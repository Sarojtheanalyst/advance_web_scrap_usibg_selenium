# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=Sh8ZYHnb86c")

time.sleep(30)

driver.execute_script("window.scrollTo(0, 500);")

time.sleep(10)

driver.execute_script("window.scrollTo(500,document.documentElement.scrollHeight);")
time.sleep(10)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time


driver = webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=Svp2MXZOXpQ")

time.sleep(10)
#driver.execute_script("window.scrollTo(0, 500);")


def scroll_and_get_height():
    last_height = driver.execute_script("return document.documentElement.scrollHeight")

    while True:
        driver.execute_script("window.scrollTo(500, document.documentElement.scrollHeight);")

        
        time.sleep(30)

        # Get the new height of the page
        new_height = driver.execute_script("return document.documentElement.scrollHeight")

      
        if new_height == last_height:
            break

        last_height = new_height

    return new_height


new_height = scroll_and_get_height()


driver.quit()

# Print the new height
print(new_height)

# %%
# /html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer[27]/ytd-comment-view-model/div[3]/div[2]/ytd-expander/div/yt-attributed-string/span

# %%
driver = webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=Sh8ZYHnb86c")

time.sleep(30)

driver.execute_script("window.scrollTo(0, 500);")
counter=1
time.sleep(10)
while True:
    
    for i in range(1,20):
        i=i+1
        datas=driver.find_elements(By.XPATH, f'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer[{i}]/ytd-comment-view-model/div[3]/div[2]/ytd-expander/div').text
        print(datas)
    driver.execute_script("window.scrollTo(500,document.documentElement.scrollHeight);")
    
    
    


time.sleep(10)
driver.quit()

# %%
# yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap
# yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap

# %%
# works perfectly

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=8Z-T5h_yJAI&list=RDJ8NogGY5McA&index=5")
time.sleep(10)

driver.execute_script("window.scrollTo(0, 500);")
time.sleep(10)
last_height = driver.execute_script("return document.documentElement.scrollHeight")
start=1
end=20
while True:
    driver.execute_script("window.scrollTo(500, document.documentElement.scrollHeight);")
    time.sleep(30)  
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break  
    last_height = new_height
    for i in range(start,end):
        comments = driver.find_element(By.XPATH, f'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer[{i}]/ytd-comment-view-model/div[3]/div[2]/ytd-expander/div/yt-attributed-string/span').text
        print(comments)
        print("\n")
    start=end
    end=start+20
    print("______________________________________________________________________")
    
driver.quit()
# Out:
# आती सुन्दर song
#
#
# यो song दिनमा एकचोटी नसुनी मन् नैं मान्दैन
# Next level songs
#
#
# स्याबास ! तिम्रो भबिस्य राम्रो छ नेपाली संगीत मा अरु मेहनत गर है भाइ !
#
#
# Back to back dami aaye ra ko xa hai
#
#
# Jhari पर्दा रुनेगर्छु आंसू पनी देखि daina .
#
#
# 2024 मा सुन्नी जति यता ️
#
#
# Rg spok
# Vanda
# Rg Ayub viral raicha ta
# Always spok dami
#
#
# This song got me into my feelings….Am an African (Kenyan) I have Nepali friends whom translated the song to me nd it’s very beautiful…Sham and Rohit Tamang are making this Jam known all over …this song is  a hit
#
#
# Katti wait greko maile yo rap ko lagi finally
#
#
# "Aama le sodnu va tyo nani sanga boldai xas"..🥹 This line hits different yaar..
#
#
# झरी पर्दा रुने गर्छु आँसु पनि देखिदैन
#
#
# Amazing rap best best best song jhari parda rune garxu ASU Pani dekhidain best line babal k socheko Vanda ni amazing ️️️best of luck bro
#
#
# Last man paro arko video ko lagi  parkhiraxu
# Touching heart ️️
#
#
# ...

# %%
# practice

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
comment=[]
driver = webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=iasxMdSu7Jo&list=RDiasxMdSu7Jo&start_radio=1")
time.sleep(30)

driver.execute_script("window.scrollTo(0, 500);")
time.sleep(10)
last_height = driver.execute_script("return document.documentElement.scrollHeight")
start=1
end=20
while True:
    driver.execute_script("window.scrollTo(500, document.documentElement.scrollHeight);")
    time.sleep(60)  
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break  
    last_height = new_height
    for i in range(start,end):
        comments = driver.find_element(By.XPATH, f'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer[{i}]/ytd-comment-view-model/div[3]/div[2]/ytd-expander/div/yt-attributed-string/span').text
        print(comments)
        comment.append(comments)
        print("\n")
    start=end
    end=start+20
    print("______________________________________________________________________")
    
driver.quit()
# Out:
# Meri love story me is movie se hi shuru Hui or jis se me pyar krti thi wo is song ko computer pr pura din sunte rehte the sab dost bhi pareshan the isnse ab hamari shadi ho gayi or jb ye song sunti hu to sochti hu k lgta tha k hm kabhi ek ho payenge ya nhi but bhagwan ne meri bat suni hamari shadi bhi ho gai or do beti bhi h  bs zindagi ne bht kuch dikhaya h ab bs aage chalte Jana h hamare pyar ko nazar na lage
#
#
# This era of bollywood song was something else. All 90s kid starting to fell in love and these songs ruled iur heart
#
#
# Such an underrated song, deserves millions of likes.
#
#
# Such an innocent love story this song deserves more and more views
#
#
# Love back then was so simple..no fakeness no materialistic wishes only pure love ️
#
#
# A beautiful lady said this was her favorite song and we were in so love at that time. Whenever I come across this song, I remember her. We are not together now but hey I miss you.
#
#
# 14 sal ki Umar me ye song sunna tha school time
# ...

# %%
for i in comment:
    print(i.strip())
# Out:
# Meri love story me is movie se hi shuru Hui or jis se me pyar krti thi wo is song ko computer pr pura din sunte rehte the sab dost bhi pareshan the isnse ab hamari shadi ho gayi or jb ye song sunti hu to sochti hu k lgta tha k hm kabhi ek ho payenge ya nhi but bhagwan ne meri bat suni hamari shadi bhi ho gai or do beti bhi h  bs zindagi ne bht kuch dikhaya h ab bs aage chalte Jana h hamare pyar ko nazar na lage
# This era of bollywood song was something else. All 90s kid starting to fell in love and these songs ruled iur heart
# Such an underrated song, deserves millions of likes.
# Such an innocent love story this song deserves more and more views
# Love back then was so simple..no fakeness no materialistic wishes only pure love ️
# A beautiful lady said this was her favorite song and we were in so love at that time. Whenever I come across this song, I remember her. We are not together now but hey I miss you.
# 14 sal ki Umar me ye song sunna tha school time
# ...
