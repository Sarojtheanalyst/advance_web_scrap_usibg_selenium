# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get("https://www.instagram.com/")


username=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[1]/div/label/input")
username.send_keys("saroj_giri45")
password=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[2]/div/label/input")
password.send_keys("sarojtheanalyst")
time.sleep(5)
# log in 
driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[3]/button").click()
print("log in sucessfully")

# not now 
driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div/div/div/div").click()


# not now 
driver.find_element(By.XPATH,"/html/body/div[5]/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[3]/button[2]").click()



driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div/div[1]/div[1]/div[2]/div/div/div/div/div[2]/div[8]/div/span/div/a/div").click()


driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div/div[1]/div[2]/div/div[1]/section/main/div/header/section[3]/ul/li[2]/div/a").click()

names=driver.find_element(By.TAGNAME,"span")

for name in names:
    print(name.text)




# /html/body/div[1]/div/div/div[2]/div/div/div[1]/div[2]/div/div[1]/section/main/div/header/section[3]/ul/li[2]/div/a
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[49], line 18
#      14 driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[3]/button").click()
#      17 # not now
# ---> 18 driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div/div/div/div").click()
#      21 # not now
#      22 driver.find_element(By.XPATH,"/html/body/div[5]/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[3]/button[2]").click()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
# extract the following and followers of the persons 

from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get("https://www.instagram.com/")
time.sleep(5)
username=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[1]/div/label/input")
username.send_keys("saroj_giri45")
password=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[2]/div/label/input")
password.send_keys("sarojtheanalyst")
time.sleep(5)
# log in 

driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[3]/button").click()
print("log in sucessfully")
time.sleep(5)

driver.get("https://www.instagram.com/suman_tamang_/")
time.sleep(3)

datas=driver.find_elements(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div[1]/section/main/div/header/section[3]/ul")
for i in datas:
    print(i.text)


# x1dm5mii x16mil14 xiojian x1yutycm x1lliihq x193iq5w xh8yej3
# Out:
# log in sucessfully
# 17 posts
# 1,404 followers
# 1,380 following

# %%
# x1lliihq x193iq5w x6ikm8r x10wlt62 xlyipyv xuxw1ft

# suman_tamang_  , makeupwith_sophie , 
aashna.a_, 
____sandesh72311

# %%
____sandesh72311

# %%
# extract the following and followers of the persons 

from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get("https://www.instagram.com/")
time.sleep(5)
username=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[1]/div/label/input")
username.send_keys("saroj_giri45")
password=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[2]/div/label/input")
password.send_keys("sarojtheanalyst")
time.sleep(5)
# log in 

driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[3]/button").click()
print("log in sucessfully")
time.sleep(5)


names=['suman_tamang_','makeupwith_sophie','aashna.a_','____sandesh72311']
counter=0
for i in names:
    driver.get(f"https://www.instagram.com/{i}/")
    time.sleep(3)
    
    datas=driver.find_elements(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div[1]/section/main/div/header/section[3]/ul")
    for i in datas:
        print(names[counter])
        print(i.text)
        print("\n\n")
    counter+=1
        

driver.close()
# x1dm5mii x16mil14 xiojian x1yutycm x1lliihq x193iq5w xh8yej3
# Out:
# log in sucessfully
# suman_tamang_
# 17 posts
# 1,404 followers
# 1,380 following
#
#
#
# makeupwith_sophie
# 10 posts
# 908 followers
# 687 following
#
#
#
# aashna.a_
# 4 posts
# 355 followers
# 361 following
#
#
#
# ____sandesh72311
# 1 post
# 121 followers
# 136 following

# %%
names=['suman_tamang_','makeupwith_sophie','aashna.a_','____sandesh72311']

# %%
# get the followrs names 
driver = webdriver.Chrome()
driver.get("https://www.instagram.com/")
time.sleep(5)
username=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[1]/div/label/input")
username.send_keys("saroj_giri45")
password=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[2]/div/label/input")
password.send_keys("sarojtheanalyst")
time.sleep(3)

driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[3]/button").click()
print("log in sucessfully")
time.sleep(5)

# log in 

driver.get('https://www.instagram.com/sansi_gautam/')
time.sleep(4)

followers_link = driver.find_element(By.XPATH, '//a[contains(@href,"/followers/")]')
followers_link.click()

page_sourcr= driver.page_source
# Clean up
driver.quit()
# Out:
# log in sucessfully

# %%
page_sourcr
# Out:
# '<html class="_9dls _ar44 js-focus-visible _aa4d __fb-dark-mode" lang="en" dir="ltr" data-js-focus-visible=""><head><link data-default-icon="https://static.cdninstagram.com/rsrc.php/v3/yI/r/VsNE-OHk_8a.png" rel="icon" sizes="192x192" href="https://static.cdninstagram.com/rsrc.php/v3/yI/r/VsNE-OHk_8a.png"><meta name="bingbot" content="noarchive"><meta name="robots" content="noarchive, noimageindex"><meta charset="utf-8"><meta name="apple-mobile-web-app-status-bar-style" content="default"><meta name="mobile-web-app-capable" content="yes"><meta id="viewport" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=2, viewport-fit=cover"><link rel="preconnect" href="https://scontent.cdninstagram.com"><link rel="dns-prefetch" href="https://scontent.cdninstagram.com"><meta name="theme-color" content="#242526"><meta name="theme-color" content="#000000" media="(prefers-color-scheme: dark)"><link rel="apple-touch-icon" sizes="76x76" href="https://static.cdn
# ...

# %%
# https://www.instagram.com/direct/t/120358882687917/

# %%
driver = webdriver.Chrome()
driver.get("https://www.instagram.com/")
time.sleep(5)
username=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[1]/div/label/input")
username.send_keys("saroj_giri45")
password=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[2]/div/label/input")
password.send_keys("sarojtheanalyst")
time.sleep(5)
# log in 

driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[3]/button").click()
print("log in sucessfully")
time.sleep(5)
driver.get("https://www.instagram.com/direct/t/120358882687917/")
time.sleep(5)

for i in range(10):
    elems=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/section/div/div/div/div[1]/div/div[2]/div/div/div/div/div/div/div[2]/div/div/div[2]/div/div/div[2]/div/div[1]/p")
    elems.send_keys("hello hyy how are you ")
    driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/section/div/div/div/div[1]/div/div[2]/div/div/div/div/div/div/div[2]/div/div/div[2]/div/div/div[3]").click()
    time.sleep(2)
driver.quit()
# Out:
# log in sucessfully

# %%
# /html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/section/div/div/div/div[1]/div/div[2]/div/div/div/div/div/div/div[2]/div/div/div[2]/div/div/div[3]

# %%
# class="x6s0dn4 x1q4h3jn x78zum5 x1y1aw1k xxbr6pl xwib8y2 xbbxn1n x87ps6o x1wq6e7o x1di1pr7 x1h4gsww xux34ky x1ypdohk x1l895ks"

# %%
# https://www.instagram.com/notifications/

# %%
driver = webdriver.Chrome()
driver.get("https://www.instagram.com/")
time.sleep(5)
username=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[1]/div/label/input")
username.send_keys("saroj_giri45")
password=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[2]/div/label/input")
password.send_keys("sarojtheanalyst")
time.sleep(5)
# log in 

driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[3]/button").click()
print("log in sucessfully")
time.sleep(5)
driver.get("https://www.instagram.com/notifications/")
time.sleep(5)
nots=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div/div/div[4]")
demo=nots.find_elements(By.TAG_NAME,"span")
print(len(demo))
# Out:
# log in sucessfully
# 150

# %%
print(nots.text)
# Out:
# asmi_ta4851
# Asmita Shrestha
# New to Instagram
# Follow
# makeup_hina_
# Hina_makeup
# New to Instagram
# Follow
# dreamdrive84
# DreamDrive84
# Suggested for you
# Follow
# misterchameleon007
# Sandesh Kc
# Suggested for you
# Follow
# explo_renepal57
# Ghumante 💚👋
# Suggested for you
# Follow
# pragya.chaauhaan
# Pragya Chauhan
# Suggested for you
# Follow
# giri.kavya
# Kavya Giri
# Suggested for you
# Follow
# i_m_steverogerrs
# HRitik mishra
# Suggested for you
# Follow
# careergirlfinance
# Career Girl Finance | Based on🇳🇵
# Followed by deepshovakarki
# Follow
# _smariikaa
# Smarika Shrestha
# Suggested for you
# Follow
# kusumgiri333
# Kusum Giri
# Suggested for you
# Follow
# namratahere_
# Namrata Lamsal
# Suggested for you
# Follow
# samrachanagiri
# Samrachana Giri
# Suggested for you
# Follow
# sandeshpanthi1
# Sandesh Panthi
# Suggested for you
# Follow
# _prashant_dangol
# Prashant Dangol
# Suggested for you
# Follow
# anita_gyawali57
# Anita Gyawali
# ...

# %%
for i
# Out:
# Hina_makeup

# %%
# x9f619 x1n2onr6 x1ja2u2z x1qjc9v5 x78zum5 xdt5ytf x1iyjqo2 xl56j7k xeuugli

# %%
driver = webdriver.Chrome()
driver.get("https://www.instagram.com/")
time.sleep(5)
username=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[1]/div/label/input")
username.send_keys("saroj_giri45")
password=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[2]/div/label/input")
password.send_keys("sarojtheanalyst")
time.sleep(5)
# log in 

driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div/section/main/article/div[2]/div[1]/div[2]/div/form/div/div[3]/button").click()
print("log in sucessfully")
time.sleep(5)
driver.get("https://www.instagram.com/notifications/")
time.sleep(5)
nots=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div/div/div[4]")
demo=nots.find_elements(By.CLASS_NAME,"x1dm5mii x16mil14 xiojian x1yutycm x1lliihq x193iq5w xh8yej3")


for i in demo:
    print(i.text)
# Out:
# log in sucessfully
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[158], line 16
#      14 driver.get("https://www.instagram.com/notifications/")
#      15 time.sleep(5)
# ---> 16 nots=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div/div/div[4]")
#      17 demo=nots.find_elements(By.CLASS_NAME,"x1dm5mii x16mil14 xiojian x1yutycm x1lliihq x193iq5w xh8yej3")
#      20 for i in demo:
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
# ...
